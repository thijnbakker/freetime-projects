# %% [markdown]
# # Description
#
# A company has a lot of client data in  word, pdf, images etc. containing different types of graphs. They want to have this data stored in their database.
#
# They approached you with a dataset of extracted plots of different types, and want you to:
#
# __Classify images of plots into different classes: (2pts)__
#
# You are provided with a dataset.zip, containing images of different types of plots.
# Tasks:
#
# a) Clean the dataset (remove any file which is corrupted, make sure images are in
# same format (.jpg or .png ))
#
# b) Build a classifier training code (pytorch or keras or classical ML  model anything is
# fine)
#
# c) Do the accuracy metrics analysis
#
# d) Save model
#
# e) Inference code testing your model on any image from the dataset
#
#
# __Deliverables:__
# 1. Complete code or notebook
# 2. Saved model file
# 3. Documentation containing instructions to run your code and a requirements.txt (You can also make use of Markdown cells if you are using a notebook)

# %%
# Add all the needed imports
import os
from torchvision import datasets, transforms
from PIL import Image
import shutil
import random

# %% [markdown]
# ## A) Clean the dataset (remove any file which is corrupted, make sure images are in same format (.jpg or .png ))

# %%
# Create the valid extensions tuple
valid_extensions = ('.jpg', '.jpeg', '.png', '.ppm', '.bmp', '.tif', '.tiff', '.webp')

def is_valid_image(file):
    return file.lower().endswith(valid_extensions)

all_images_dataset = datasets.ImageFolder(
    'dataset_part1',
    transform=transforms.ToTensor(),
    is_valid_file=is_valid_image
)

# Show the number of images in the dataset
print(f"Number of images in the dataset: {len(all_images_dataset)}")

# Show the number of classes in the dataset
print(f"Number of classes in the dataset: {len(all_images_dataset.classes)}")
# Out:
# Number of images in the dataset: 3190
# Number of classes in the dataset: 5

# %% [markdown]
# ### !!! This number is incorrect because there are also files like GIF etc. The total amount of images are: "3202" !!!

# %% [markdown]
# ### If we change the images to their correct type we will lose only 12 images! This is perfectly fine!

# %% [markdown]
# ### Make a dataset with only ".png" images

# %%
# Path to original fixed dataset
source_dir = 'dataset_part1'

# Path to new location
output_dir = 'dataset_part1_fixed'
os.makedirs(output_dir, exist_ok=True)

# Load dataset to get image paths and labels
transform = transforms.ToTensor()
fixed_dataset = datasets.ImageFolder(source_dir, transform=transform)

# Save all images in the new location
for i, (img_path, label) in enumerate(fixed_dataset.imgs):
    class_name = fixed_dataset.classes[label]
    class_dir = os.path.join(output_dir, class_name)
    os.makedirs(class_dir, exist_ok=True)

    # Save image with consistent name format
    new_filename = f'image_{i}.png'
    new_path = os.path.join(class_dir, new_filename)

    # Convert and save as .jpg
    img = Image.open(img_path).convert('RGB')
    img.save(new_path, 'PNG')

print(f"✅ Fixed dataset saved to: {output_dir}")
# Out:
# ✅ Fixed dataset saved to: dataset_part1_fixed

# %%
# Load the fixed dataset
fixed_dataset = datasets.ImageFolder(
    output_dir,
    transform=transforms.ToTensor(),
    is_valid_file=is_valid_image
)

# Show the number of images in the fixed dataset
print(f"Number of images in the fixed dataset: {len(fixed_dataset)}")

# Show the number of classes in the fixed dataset
print(f"Number of classes in the fixed dataset: {len(fixed_dataset.classes)}")
# Out:
# Number of images in the fixed dataset: 3190
# Number of classes in the fixed dataset: 5

# %%
# Check if the dataset is fixed
for image_path in fixed_dataset.imgs:
    print(f"Image path: {image_path[0]}, Extension: {os.path.splitext(image_path[0])[1]}")
# Out:
# Image path: dataset_part1_fixed\bargraph\image_0.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_1.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_10.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_100.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_101.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_102.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_103.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_104.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_105.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_106.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_107.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_108.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_109.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_11.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_110.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_111.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_112.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_113.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_114.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_115.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_116.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_117.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_118.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_119.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_12.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_120.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_121.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_122.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_123.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_124.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_125.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_126.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_127.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_128.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_129.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_13.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_130.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_131.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_132.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_133.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_134.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_135.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_136.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_137.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_138.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_139.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_14.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_140.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_141.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_142.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_143.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_144.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_145.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_146.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_147.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_148.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_149.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_15.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_150.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_151.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_152.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_153.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_154.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_155.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_156.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_157.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_158.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_159.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_16.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_160.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_161.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_162.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_163.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_164.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_165.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_166.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_167.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_168.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_169.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_17.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_170.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_171.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_172.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_173.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_174.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_175.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_176.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_177.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_178.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_179.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_18.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_180.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_181.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_182.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_183.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_184.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_185.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_186.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_187.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_188.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_189.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_19.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_190.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_191.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_192.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_193.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_194.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_195.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_196.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_197.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_198.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_199.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_2.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_20.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_200.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_201.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_202.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_203.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_204.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_205.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_206.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_207.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_208.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_209.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_21.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_210.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_211.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_212.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_213.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_214.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_215.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_216.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_217.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_218.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_219.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_22.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_220.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_221.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_222.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_223.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_224.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_225.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_226.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_227.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_228.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_229.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_23.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_230.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_231.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_232.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_233.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_234.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_235.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_236.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_237.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_238.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_239.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_24.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_240.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_241.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_242.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_243.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_244.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_245.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_246.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_247.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_248.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_249.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_25.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_250.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_251.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_252.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_253.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_254.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_255.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_256.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_257.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_258.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_259.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_26.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_260.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_261.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_262.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_263.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_264.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_265.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_266.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_267.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_268.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_269.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_27.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_270.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_271.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_272.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_273.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_274.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_275.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_276.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_277.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_278.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_279.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_28.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_280.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_281.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_282.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_283.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_284.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_285.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_286.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_287.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_288.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_289.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_29.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_290.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_291.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_292.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_293.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_294.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_295.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_296.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_297.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_298.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_299.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_3.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_30.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_300.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_301.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_302.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_303.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_304.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_305.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_306.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_307.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_308.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_309.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_31.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_310.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_311.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_312.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_313.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_314.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_315.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_316.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_317.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_318.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_319.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_32.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_320.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_321.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_322.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_323.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_324.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_325.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_326.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_327.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_328.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_329.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_33.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_330.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_331.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_332.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_333.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_334.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_335.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_336.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_337.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_338.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_339.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_34.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_340.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_341.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_342.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_343.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_344.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_345.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_346.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_347.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_348.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_349.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_35.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_350.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_351.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_352.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_353.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_354.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_355.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_356.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_357.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_358.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_359.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_36.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_360.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_361.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_362.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_363.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_364.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_365.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_366.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_367.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_368.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_369.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_37.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_370.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_371.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_372.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_373.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_374.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_375.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_376.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_377.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_378.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_379.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_38.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_380.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_381.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_382.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_383.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_384.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_385.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_386.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_387.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_388.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_389.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_39.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_390.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_391.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_392.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_393.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_394.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_395.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_396.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_397.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_398.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_399.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_4.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_40.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_400.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_401.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_402.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_403.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_404.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_405.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_406.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_407.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_408.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_409.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_41.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_410.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_411.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_412.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_413.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_414.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_415.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_416.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_417.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_418.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_419.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_42.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_420.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_421.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_422.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_423.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_424.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_425.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_426.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_427.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_428.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_429.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_43.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_430.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_431.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_432.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_433.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_434.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_435.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_436.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_437.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_438.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_439.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_44.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_440.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_441.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_442.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_443.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_444.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_445.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_446.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_447.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_448.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_449.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_45.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_450.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_451.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_452.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_453.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_454.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_455.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_456.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_457.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_458.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_459.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_46.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_460.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_461.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_462.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_463.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_464.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_465.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_466.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_467.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_468.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_469.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_47.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_470.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_471.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_472.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_473.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_474.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_475.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_476.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_477.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_478.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_479.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_48.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_480.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_481.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_482.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_483.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_484.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_485.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_486.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_487.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_488.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_489.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_49.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_490.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_491.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_492.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_493.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_494.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_495.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_496.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_497.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_498.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_499.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_5.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_50.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_500.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_501.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_502.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_503.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_504.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_505.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_506.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_507.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_508.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_509.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_51.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_510.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_511.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_512.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_513.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_514.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_515.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_516.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_517.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_518.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_519.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_52.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_520.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_521.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_522.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_523.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_524.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_525.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_526.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_527.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_528.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_529.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_53.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_530.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_531.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_532.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_54.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_55.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_56.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_57.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_58.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_59.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_6.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_60.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_61.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_62.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_63.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_64.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_65.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_66.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_67.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_68.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_69.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_7.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_70.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_71.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_72.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_73.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_74.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_75.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_76.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_77.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_78.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_79.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_8.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_80.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_81.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_82.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_83.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_84.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_85.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_86.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_87.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_88.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_89.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_9.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_90.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_91.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_92.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_93.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_94.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_95.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_96.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_97.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_98.png, Extension: .png
# Image path: dataset_part1_fixed\bargraph\image_99.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1000.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1001.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1002.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1003.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1004.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1005.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1006.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1007.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1008.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1009.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1010.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1011.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1012.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1013.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1014.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1015.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1016.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1017.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1018.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1019.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1020.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1021.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1022.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1023.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1024.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1025.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1026.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1027.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1028.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1029.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1030.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1031.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1032.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1033.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1034.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1035.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1036.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1037.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1038.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1039.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1040.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1041.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1042.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1043.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1044.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1045.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1046.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1047.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1048.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1049.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1050.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1051.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1052.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1053.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1054.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1055.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1056.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1057.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1058.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1059.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1060.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1061.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1062.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1063.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1064.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1065.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1066.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1067.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1068.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1069.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1070.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1071.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1072.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1073.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1074.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1075.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1076.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1077.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1078.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1079.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1080.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1081.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1082.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1083.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1084.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1085.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1086.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1087.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1088.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1089.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1090.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1091.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1092.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1093.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1094.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1095.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1096.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1097.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1098.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1099.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1100.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1101.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1102.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1103.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1104.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1105.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1106.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1107.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1108.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1109.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1110.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1111.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1112.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1113.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1114.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1115.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1116.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1117.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1118.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1119.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1120.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1121.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1122.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1123.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1124.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1125.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1126.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1127.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1128.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1129.png, Extension: .png
# Image path: dataset_part1_fixed\flowchart\image_1130.png, Extension: .png
# ...
# Image path: dataset_part1_fixed\scatterplot\image_2980.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2981.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2982.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2983.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2984.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2985.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2986.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2987.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2988.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2989.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2990.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2991.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2992.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2993.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2994.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2995.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2996.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2997.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2998.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_2999.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3000.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3001.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3002.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3003.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3004.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3005.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3006.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3007.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3008.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3009.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3010.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3011.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3012.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3013.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3014.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3015.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3016.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3017.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3018.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3019.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3020.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3021.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3022.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3023.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3024.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3025.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3026.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3027.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3028.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3029.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3030.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3031.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3032.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3033.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3034.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3035.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3036.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3037.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3038.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3039.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3040.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3041.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3042.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3043.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3044.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3045.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3046.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3047.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3048.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3049.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3050.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3051.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3052.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3053.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3054.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3055.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3056.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3057.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3058.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3059.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3060.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3061.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3062.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3063.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3064.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3065.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3066.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3067.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3068.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3069.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3070.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3071.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3072.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3073.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3074.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3075.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3076.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3077.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3078.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3079.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3080.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3081.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3082.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3083.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3084.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3085.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3086.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3087.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3088.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3089.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3090.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3091.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3092.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3093.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3094.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3095.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3096.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3097.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3098.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3099.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3100.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3101.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3102.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3103.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3104.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3105.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3106.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3107.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3108.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3109.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3110.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3111.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3112.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3113.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3114.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3115.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3116.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3117.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3118.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3119.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3120.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3121.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3122.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3123.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3124.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3125.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3126.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3127.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3128.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3129.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3130.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3131.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3132.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3133.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3134.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3135.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3136.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3137.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3138.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3139.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3140.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3141.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3142.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3143.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3144.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3145.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3146.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3147.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3148.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3149.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3150.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3151.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3152.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3153.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3154.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3155.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3156.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3157.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3158.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3159.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3160.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3161.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3162.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3163.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3164.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3165.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3166.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3167.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3168.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3169.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3170.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3171.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3172.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3173.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3174.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3175.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3176.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3177.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3178.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3179.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3180.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3181.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3182.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3183.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3184.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3185.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3186.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3187.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3188.png, Extension: .png
# Image path: dataset_part1_fixed\scatterplot\image_3189.png, Extension: .png

# %% [markdown]
# ### The conversion went well we kept all the files and turned them into ".png" or ".jpg". Now lets see if they all work. And if there are any corrupt files.

# %%
folder_path = 'dataset_part1_fixed'
corrupt_files = []

for root, _, files in os.walk(folder_path):
    for file in files:
        file_path = os.path.join(root, file)
        try:
            with Image.open(file_path) as img:
                img.verify()  # Verify that the file is not corrupt
        except Exception as e:
            corrupt_files.append(file_path)

if corrupt_files:
    print(f"Found {len(corrupt_files)} corrupt files:")
    for corrupt_file in corrupt_files:
        print(corrupt_file)
else:
    print("No corrupt files found in the dataset.")
# Out:
# No corrupt files found in the dataset.

# %% [markdown]
# ### Both work perfectly so now it is onto the next step!

# %% [markdown]
# ### Resize the images to ideal size

# %%
# Define a transform to resize images to 250x250
resize_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Grayscale(num_output_channels=1),  # Convert to Grayscale

])

# Apply the transform to the dataset
resized_dataset = datasets.ImageFolder(
    folder_path,
    transform=resize_transform,
)

# Verify the transformation by checking the size of the first image
sample_image, _ = resized_dataset[0]
print(f"Resized image shape: {sample_image.shape}")
# Out:
# Resized image shape: torch.Size([1, 256, 256])

# %% [markdown]
# ### Save the resized images to a new directory

# %%
output_dir = 'dataset_part1_resized'
os.makedirs(output_dir, exist_ok=True)

# Create subdirectories for each class
for class_name in resized_dataset.classes:
    os.makedirs(os.path.join(output_dir, class_name), exist_ok=True)
# Copy and resize images to the new directory
for i, (image, label) in enumerate(resized_dataset):
    class_name = resized_dataset.classes[label]
    image_path = os.path.join(output_dir, class_name, f'image_{i}.png')
    image_pil = transforms.ToPILImage()(image)
    image_pil.save(image_path)
# Print the number of images in the resized dataset
resized_dataset = datasets.ImageFolder(
    output_dir,
    transform=transforms.ToTensor(),
)
print(f"Number of images in the resized dataset: {len(resized_dataset)}")
# Print the number of classes in the resized dataset
print(f"Number of classes in the resized dataset: {len(resized_dataset.classes)}")
# Out:
# Number of images in the resized dataset: 3190
# Number of classes in the resized dataset: 5

# %% [markdown]
# ### Split the data

# %%
transform = transforms.ToTensor()

def split_dataset(source_dir, dest_dir, split_ratio=0.8):
    for class_name in os.listdir(source_dir):
        class_dir = os.path.join(source_dir, class_name)
        if not os.path.isdir(class_dir): continue

        images = os.listdir(class_dir)
        random.shuffle(images)
        split_point = int(len(images) * split_ratio)

        train_images = images[:split_point]
        val_images = images[split_point:]

        for phase, phase_images in zip(['train', 'val'], [train_images, val_images]):
            phase_class_dir = os.path.join(dest_dir, phase, class_name)
            os.makedirs(phase_class_dir, exist_ok=True)
            for img in phase_images:
                shutil.copy2(os.path.join(class_dir, img), os.path.join(phase_class_dir, img))

split_dataset('dataset_part1_resized', 'dataset_part1_split')

# %%
# Check the number of images in the train and validation directories
train_dir = 'dataset_part1_split/train'
val_dir = 'dataset_part1_split/val'

train_count = sum([len(files) for _, _, files in os.walk(train_dir)])
val_count = sum([len(files) for _, _, files in os.walk(val_dir)])
print(f"Number of training images: {train_count}")
print(f"Number of validation images: {val_count}")
# Out:
# Number of training images: 2551
# Number of validation images: 639

# %% [markdown]
# ### Now the data is ready for training. Might add Data Augmentation later.
