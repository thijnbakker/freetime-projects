# %% [markdown]
# # Description
#
# A company has a lot of client data in  word, pdf, images etc. containing different types of graphs. They want to have this data stored in their database.
#
# They approached you with a dataset of extracted plots of different types, and want you to:
#
# __Classify images of plots into different classes: (2pts)__
#
# You are provided with a dataset.zip, containing images of different types of plots.
# Tasks:
#
# a) Clean the dataset (remove any file which is corrupted, make sure images are in
# same format (.jpg or .png ))
#
# b) Build a classifier training code (pytorch or keras or classical ML  model anything is
# fine)
#
# c) Do the accuracy metrics analysis
#
# d) Save model
#
# e) Inference code testing your model on any image from the dataset
#
#
# __Deliverables:__
# 1. Complete code or notebook
# 2. Saved model file
# 3. Documentation containing instructions to run your code and a requirements.txt (You can also make use of Markdown cells if you are using a notebook)

# %%
# Add all the needed imports
import keras.backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt

import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Split the data

# %%
image_dir = 'dataset_part1_split'
image_size = 256

# %% [markdown]
# ### Add Data Augmentation

# %%
# Setup a generator for training
# Training images
train_image_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.15,
    fill_mode='nearest'
)

train_image_generator = train_image_datagen.flow_from_directory(
    f'{image_dir}/train',
    target_size=(image_size, image_size),
    batch_size=16,
    class_mode="categorical",
    color_mode='grayscale',
    seed=42)

# val images
val_image_datagen = ImageDataGenerator(rescale=1./255)

val_image_generator = val_image_datagen.flow_from_directory(
    f'{image_dir}/val',
    target_size=(image_size, image_size),
    batch_size=16,
    class_mode="categorical",
    color_mode='grayscale',
    seed=42,
    shuffle=False # Don't shuffle the validation data
)
# Out:
# Found 2551 images belonging to 5 classes.
# Found 639 images belonging to 5 classes.

# %%
def f1(y_true, y_pred):
    def recall_m(y_true, y_pred):
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = TP / (Positives+K.epsilon())
        return recall
    
    def precision_m(y_true, y_pred):
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Pred_Positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = TP / (Pred_Positives+K.epsilon())
        return precision
    
    precision, recall = precision_m(y_true, y_pred), recall_m(y_true, y_pred)
    
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    verbose=1,
    min_lr=1e-6
)

# %%
def simple_cnn_model(input_shape, num_classes):
    model = Sequential()
    model.add(Conv2D(32, (3,3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D())
    model.add(Conv2D(64, (3,3), activation='relu'))
    model.add(MaxPooling2D())
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))  # softmax for multi-class classification

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', f1])
    model.summary()
    return model

# Build model
input_shape = (image_size, image_size, 1)  # grayscale
num_classes = train_image_generator.num_classes
model = simple_cnn_model(input_shape, num_classes)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      320
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 246016)            0
#
#  dense (Dense)               (None, 128)               31490176
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 31,509,637
# Trainable params: 31,509,637
# Non-trainable params: 0
# _________________________________________________________________

# %%
# EarlyStopping()
cb = EarlyStopping(monitor='val_loss',
                   patience=10,
                   restore_best_weights='True',
                   mode='min')

# %% [markdown]
# ### Now lets train for a bit longer

# %%
# This is where the magic happens
history = model.fit(
    train_image_generator,
    steps_per_epoch=len(train_image_generator),
    epochs=100,
    validation_data = val_image_generator,
    validation_steps = val_image_generator.samples//16,
    callbacks=[cb, lr_scheduler]
)
# Out:
# Epoch 1/100
# 160/160 [==============================] - 10s 44ms/step - loss: 1.9409 - accuracy: 0.3152 - f1: 0.0996 - val_loss: 1.3147 - val_accuracy: 0.4439 - val_f1: 0.2141 - lr: 0.0010
# Epoch 2/100
# 160/160 [==============================] - 7s 41ms/step - loss: 1.3440 - accuracy: 0.4434 - f1: 0.2364 - val_loss: 1.1059 - val_accuracy: 0.5545 - val_f1: 0.3032 - lr: 0.0010
# Epoch 3/100
# 160/160 [==============================] - 7s 42ms/step - loss: 1.1757 - accuracy: 0.5057 - f1: 0.3392 - val_loss: 1.0179 - val_accuracy: 0.5561 - val_f1: 0.3271 - lr: 0.0010
# Epoch 4/100
# 160/160 [==============================] - 7s 41ms/step - loss: 1.1379 - accuracy: 0.5257 - f1: 0.3642 - val_loss: 0.9317 - val_accuracy: 0.5817 - val_f1: 0.3934 - lr: 0.0010
# Epoch 5/100
# 160/160 [==============================] - 7s 41ms/step - loss: 1.0702 - accuracy: 0.5323 - f1: 0.3759 - val_loss: 0.9188 - val_accuracy: 0.5978 - val_f1: 0.3556 - lr: 0.0010
# Epoch 6/100
# 160/160 [==============================] - 7s 41ms/step - loss: 1.0068 - accuracy: 0.5735 - f1: 0.4270 - val_loss: 0.8895 - val_accuracy: 0.6090 - val_f1: 0.3657 - lr: 0.0010
# Epoch 7/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.9713 - accuracy: 0.5951 - f1: 0.4572 - val_loss: 0.8700 - val_accuracy: 0.5994 - val_f1: 0.4958 - lr: 0.0010
# Epoch 8/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.9516 - accuracy: 0.5853 - f1: 0.4725 - val_loss: 0.8346 - val_accuracy: 0.6314 - val_f1: 0.5150 - lr: 0.0010
# Epoch 9/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.9230 - accuracy: 0.6131 - f1: 0.5098 - val_loss: 0.8249 - val_accuracy: 0.6554 - val_f1: 0.4525 - lr: 0.0010
# Epoch 10/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.8896 - accuracy: 0.6280 - f1: 0.5397 - val_loss: 0.7872 - val_accuracy: 0.6651 - val_f1: 0.5035 - lr: 0.0010
# Epoch 11/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.8741 - accuracy: 0.6425 - f1: 0.5516 - val_loss: 0.8330 - val_accuracy: 0.6699 - val_f1: 0.4379 - lr: 0.0010
# Epoch 12/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.8787 - accuracy: 0.6249 - f1: 0.5286 - val_loss: 0.7677 - val_accuracy: 0.6971 - val_f1: 0.5464 - lr: 0.0010
# Epoch 13/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.8602 - accuracy: 0.6558 - f1: 0.5751 - val_loss: 0.7292 - val_accuracy: 0.7196 - val_f1: 0.5993 - lr: 0.0010
# Epoch 14/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.8184 - accuracy: 0.6739 - f1: 0.6092 - val_loss: 0.7285 - val_accuracy: 0.7099 - val_f1: 0.6389 - lr: 0.0010
# Epoch 15/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.7897 - accuracy: 0.6935 - f1: 0.6465 - val_loss: 0.6682 - val_accuracy: 0.7612 - val_f1: 0.7049 - lr: 0.0010
# Epoch 16/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.7519 - accuracy: 0.7229 - f1: 0.6843 - val_loss: 0.7096 - val_accuracy: 0.7196 - val_f1: 0.6698 - lr: 0.0010
# Epoch 17/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.7100 - accuracy: 0.7252 - f1: 0.6876 - val_loss: 0.5712 - val_accuracy: 0.7901 - val_f1: 0.7648 - lr: 0.0010
# Epoch 18/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.6804 - accuracy: 0.7452 - f1: 0.7222 - val_loss: 0.5852 - val_accuracy: 0.7756 - val_f1: 0.7481 - lr: 0.0010
# Epoch 19/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.6457 - accuracy: 0.7577 - f1: 0.7413 - val_loss: 0.5159 - val_accuracy: 0.8125 - val_f1: 0.7878 - lr: 0.0010
# Epoch 20/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.6212 - accuracy: 0.7871 - f1: 0.7647 - val_loss: 0.4902 - val_accuracy: 0.8253 - val_f1: 0.8113 - lr: 0.0010
# Epoch 21/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.6227 - accuracy: 0.7887 - f1: 0.7704 - val_loss: 0.5365 - val_accuracy: 0.8221 - val_f1: 0.7898 - lr: 0.0010
# Epoch 22/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.5950 - accuracy: 0.7907 - f1: 0.7755 - val_loss: 0.5388 - val_accuracy: 0.7981 - val_f1: 0.7792 - lr: 0.0010
# Epoch 23/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.5736 - accuracy: 0.7954 - f1: 0.7834 - val_loss: 0.5311 - val_accuracy: 0.8141 - val_f1: 0.7945 - lr: 0.0010
# Epoch 24/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.5638 - accuracy: 0.7962 - f1: 0.7848 - val_loss: 0.4990 - val_accuracy: 0.8173 - val_f1: 0.8018 - lr: 0.0010
# Epoch 25/100
# 159/160 [============================>.] - ETA: 0s - loss: 0.5429 - accuracy: 0.8158 - f1: 0.8083
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 160/160 [==============================] - 7s 41ms/step - loss: 0.5454 - accuracy: 0.8146 - f1: 0.8074 - val_loss: 0.5392 - val_accuracy: 0.7917 - val_f1: 0.7685 - lr: 0.0010
# Epoch 26/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.4860 - accuracy: 0.8303 - f1: 0.8236 - val_loss: 0.4031 - val_accuracy: 0.8494 - val_f1: 0.8397 - lr: 5.0000e-04
# Epoch 27/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.4871 - accuracy: 0.8252 - f1: 0.8192 - val_loss: 0.4204 - val_accuracy: 0.8494 - val_f1: 0.8342 - lr: 5.0000e-04
# Epoch 28/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.5039 - accuracy: 0.8224 - f1: 0.8177 - val_loss: 0.3973 - val_accuracy: 0.8494 - val_f1: 0.8480 - lr: 5.0000e-04
# Epoch 29/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.4595 - accuracy: 0.8408 - f1: 0.8374 - val_loss: 0.4451 - val_accuracy: 0.8349 - val_f1: 0.8236 - lr: 5.0000e-04
# Epoch 30/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.4513 - accuracy: 0.8408 - f1: 0.8381 - val_loss: 0.4078 - val_accuracy: 0.8462 - val_f1: 0.8504 - lr: 5.0000e-04
# Epoch 31/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.4799 - accuracy: 0.8338 - f1: 0.8280 - val_loss: 0.3849 - val_accuracy: 0.8542 - val_f1: 0.8505 - lr: 5.0000e-04
# Epoch 32/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.4211 - accuracy: 0.8506 - f1: 0.8472 - val_loss: 0.3550 - val_accuracy: 0.8638 - val_f1: 0.8637 - lr: 5.0000e-04
# Epoch 33/100
# 160/160 [==============================] - 7s 43ms/step - loss: 0.4361 - accuracy: 0.8499 - f1: 0.8442 - val_loss: 0.3640 - val_accuracy: 0.8558 - val_f1: 0.8566 - lr: 5.0000e-04
# Epoch 34/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.4250 - accuracy: 0.8456 - f1: 0.8465 - val_loss: 0.3743 - val_accuracy: 0.8574 - val_f1: 0.8636 - lr: 5.0000e-04
# Epoch 35/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.4231 - accuracy: 0.8487 - f1: 0.8456 - val_loss: 0.3838 - val_accuracy: 0.8542 - val_f1: 0.8568 - lr: 5.0000e-04
# Epoch 36/100
# 160/160 [==============================] - 7s 43ms/step - loss: 0.4108 - accuracy: 0.8554 - f1: 0.8482 - val_loss: 0.4158 - val_accuracy: 0.8526 - val_f1: 0.8544 - lr: 5.0000e-04
# Epoch 37/100
# 159/160 [============================>.] - ETA: 0s - loss: 0.4130 - accuracy: 0.8552 - f1: 0.8475
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 160/160 [==============================] - 7s 42ms/step - loss: 0.4154 - accuracy: 0.8550 - f1: 0.8474 - val_loss: 0.3626 - val_accuracy: 0.8638 - val_f1: 0.8590 - lr: 5.0000e-04
# Epoch 38/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3993 - accuracy: 0.8597 - f1: 0.8590 - val_loss: 0.3814 - val_accuracy: 0.8654 - val_f1: 0.8614 - lr: 2.5000e-04
# Epoch 39/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.3766 - accuracy: 0.8652 - f1: 0.8615 - val_loss: 0.3914 - val_accuracy: 0.8654 - val_f1: 0.8640 - lr: 2.5000e-04
# Epoch 40/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.3996 - accuracy: 0.8655 - f1: 0.8595 - val_loss: 0.3563 - val_accuracy: 0.8734 - val_f1: 0.8726 - lr: 2.5000e-04
# Epoch 41/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3820 - accuracy: 0.8652 - f1: 0.8652 - val_loss: 0.3448 - val_accuracy: 0.8702 - val_f1: 0.8728 - lr: 2.5000e-04
# Epoch 42/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3687 - accuracy: 0.8757 - f1: 0.8677 - val_loss: 0.3626 - val_accuracy: 0.8606 - val_f1: 0.8654 - lr: 2.5000e-04
# Epoch 43/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3768 - accuracy: 0.8702 - f1: 0.8675 - val_loss: 0.3413 - val_accuracy: 0.8798 - val_f1: 0.8792 - lr: 2.5000e-04
# Epoch 44/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3657 - accuracy: 0.8785 - f1: 0.8732 - val_loss: 0.3298 - val_accuracy: 0.8814 - val_f1: 0.8796 - lr: 2.5000e-04
# Epoch 45/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3652 - accuracy: 0.8773 - f1: 0.8708 - val_loss: 0.3589 - val_accuracy: 0.8654 - val_f1: 0.8703 - lr: 2.5000e-04
# Epoch 46/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3660 - accuracy: 0.8702 - f1: 0.8664 - val_loss: 0.3497 - val_accuracy: 0.8718 - val_f1: 0.8688 - lr: 2.5000e-04
# Epoch 47/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3547 - accuracy: 0.8808 - f1: 0.8792 - val_loss: 0.3540 - val_accuracy: 0.8782 - val_f1: 0.8762 - lr: 2.5000e-04
# Epoch 48/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.3695 - accuracy: 0.8757 - f1: 0.8709 - val_loss: 0.3501 - val_accuracy: 0.8718 - val_f1: 0.8679 - lr: 2.5000e-04
# Epoch 49/100
# 159/160 [============================>.] - ETA: 0s - loss: 0.3536 - accuracy: 0.8809 - f1: 0.8795
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 160/160 [==============================] - 7s 41ms/step - loss: 0.3529 - accuracy: 0.8812 - f1: 0.8799 - val_loss: 0.3595 - val_accuracy: 0.8750 - val_f1: 0.8725 - lr: 2.5000e-04
# Epoch 50/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3404 - accuracy: 0.8789 - f1: 0.8745 - val_loss: 0.3414 - val_accuracy: 0.8766 - val_f1: 0.8699 - lr: 1.2500e-04
# Epoch 51/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.3355 - accuracy: 0.8828 - f1: 0.8815 - val_loss: 0.3328 - val_accuracy: 0.8894 - val_f1: 0.8799 - lr: 1.2500e-04
# Epoch 52/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3396 - accuracy: 0.8840 - f1: 0.8816 - val_loss: 0.3342 - val_accuracy: 0.8750 - val_f1: 0.8758 - lr: 1.2500e-04
# Epoch 53/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3400 - accuracy: 0.8793 - f1: 0.8800 - val_loss: 0.3542 - val_accuracy: 0.8718 - val_f1: 0.8719 - lr: 1.2500e-04
# Epoch 54/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3417 - accuracy: 0.8828 - f1: 0.8813 - val_loss: 0.3175 - val_accuracy: 0.8894 - val_f1: 0.8882 - lr: 1.2500e-04
# Epoch 55/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3458 - accuracy: 0.8797 - f1: 0.8807 - val_loss: 0.3433 - val_accuracy: 0.8830 - val_f1: 0.8813 - lr: 1.2500e-04
# Epoch 56/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.3467 - accuracy: 0.8785 - f1: 0.8756 - val_loss: 0.3299 - val_accuracy: 0.8878 - val_f1: 0.8816 - lr: 1.2500e-04
# Epoch 57/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.3248 - accuracy: 0.8898 - f1: 0.8855 - val_loss: 0.3423 - val_accuracy: 0.8782 - val_f1: 0.8760 - lr: 1.2500e-04
# Epoch 58/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.3187 - accuracy: 0.8910 - f1: 0.8901 - val_loss: 0.3353 - val_accuracy: 0.8830 - val_f1: 0.8813 - lr: 1.2500e-04
# Epoch 59/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3450 - accuracy: 0.8820 - f1: 0.8793 - val_loss: 0.3133 - val_accuracy: 0.8910 - val_f1: 0.8834 - lr: 1.2500e-04
# Epoch 60/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3090 - accuracy: 0.8930 - f1: 0.8874 - val_loss: 0.3312 - val_accuracy: 0.8830 - val_f1: 0.8822 - lr: 1.2500e-04
# Epoch 61/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3253 - accuracy: 0.8824 - f1: 0.8833 - val_loss: 0.3220 - val_accuracy: 0.8862 - val_f1: 0.8876 - lr: 1.2500e-04
# Epoch 62/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3308 - accuracy: 0.8883 - f1: 0.8846 - val_loss: 0.3333 - val_accuracy: 0.8862 - val_f1: 0.8808 - lr: 1.2500e-04
# Epoch 63/100
# 160/160 [==============================] - 7s 41ms/step - loss: 0.3143 - accuracy: 0.8934 - f1: 0.8931 - val_loss: 0.3296 - val_accuracy: 0.8798 - val_f1: 0.8808 - lr: 1.2500e-04
# Epoch 64/100
# 159/160 [============================>.] - ETA: 0s - loss: 0.3143 - accuracy: 0.8923 - f1: 0.8944
# Epoch 64: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 160/160 [==============================] - 7s 41ms/step - loss: 0.3144 - accuracy: 0.8922 - f1: 0.8945 - val_loss: 0.3300 - val_accuracy: 0.8878 - val_f1: 0.8787 - lr: 1.2500e-04
# Epoch 65/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3207 - accuracy: 0.8867 - f1: 0.8896 - val_loss: 0.3248 - val_accuracy: 0.8926 - val_f1: 0.8848 - lr: 6.2500e-05
# Epoch 66/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3196 - accuracy: 0.8895 - f1: 0.8921 - val_loss: 0.3323 - val_accuracy: 0.8814 - val_f1: 0.8785 - lr: 6.2500e-05
# Epoch 67/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3024 - accuracy: 0.8946 - f1: 0.8922 - val_loss: 0.3319 - val_accuracy: 0.8862 - val_f1: 0.8829 - lr: 6.2500e-05
# Epoch 68/100
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3031 - accuracy: 0.8957 - f1: 0.8934 - val_loss: 0.3263 - val_accuracy: 0.8910 - val_f1: 0.8884 - lr: 6.2500e-05
# Epoch 69/100
# 160/160 [==============================] - ETA: 0s - loss: 0.3097 - accuracy: 0.8953 - f1: 0.8916
# Epoch 69: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 160/160 [==============================] - 7s 42ms/step - loss: 0.3097 - accuracy: 0.8953 - f1: 0.8916 - val_loss: 0.3153 - val_accuracy: 0.8878 - val_f1: 0.8879 - lr: 6.2500e-05

# %% [markdown]
# ## c) Do the accuracy metrics analysis

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Plot the validation f1 score
plt.figure(figsize=(12, 5))
plt.plot(history.history['f1'], label='Train F1 Score')
plt.plot(history.history['val_f1'], label='Validation F1 Score')
plt.title('Model F1 Score')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Get predictions
val_predictions = model.predict(val_image_generator)
val_pred_classes = np.argmax(val_predictions, axis=1)
val_true_classes = val_image_generator.classes

# Compute confusion matrix
conf_matrix = confusion_matrix(val_true_classes, val_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=val_image_generator.class_indices.keys(), yticklabels=val_image_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()
# Out:
# 40/40 [==============================] - 1s 11ms/step

# %% [markdown]
# ## d) Save model

# %%
# Save the model
model.save('simple_cnn_model_v4.h5')
